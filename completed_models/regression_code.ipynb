# %%
import pandas as pd
import statsmodels.formula.api as smf
from statsmodels.iolib.summary2 import summary_col
import warnings
import numpy as np
warnings.filterwarnings('ignore')

# %%
df_panel   = pd.read_csv('единицы_без_протестов_test.csv')
df_treated = pd.read_csv('протесты_test.csv')

df_panel['group'] = 0   # Контрольные муниципалитеты
df_treated['group'] = 1   # Протестные муниципалитеты

# 3. Объединяем вертикально (concatenate)
df_panel = pd.concat([df_panel, df_treated], ignore_index=True)

df_panel = df_panel[['year', 'municipality', 'oktmo',
                     'Жилье (1000 м2)', 'Дороги (%)', 'Канализация (1 м)', 'Водопровод (1 метр)',
                     'region_name', 'group']].drop_duplicates(subset=['year','municipality','oktmo', 'group'])




# df_panel.to_csv('panel_all.csv', index=False)
df_panel = df_panel[df_panel['year'].isin([2009, 2012])].reset_index(drop=True)
df_panel['post'] = (df_panel['year'] == 2012).astype(int)

df_panel = df_panel.rename(columns={
    'Жилье (1000 м2)': 'Жилье',
    'Дороги (%)': 'Дороги',
    'Канализация (1 м)': 'Канализация',
    'Водопровод (1 метр)': 'Водопровод'
})



def run_did(data, outcome):
    # Удаляем строки с пропусками по outcome
    d = data.dropna(subset=[outcome, 'group', 'post']).copy()
    formula = f'{outcome} ~ group + post + group:post + C(region_name)'
    model = smf.ols(formula, data=d).fit(cov_type='HC1')
    return model

outcomes = ['Жилье', 'Дороги', 'Канализация', 'Водопровод']
results = {o: run_did(df_panel, o) for o in outcomes}

print("\nКоэффициенты взаимодействия (group:post) и p-value:")
coef_rows = []
for o, m in results.items():
    coef = m.params.get('group:post', 0)
    pval = m.pvalues.get('group:post', 1)
    coef_rows.append([o, coef, pval])
    print(f"{o}: {coef:.4f} (p-value: {pval:.3f})")
    # print(m.summary())
# Out:
# Коэффициенты взаимодействия (group:post) и p-value:
# Жилье: -17.2191 (p-value: 0.640)
# Дороги: 20.5082 (p-value: 0.000)
# Канализация: -195.1638 (p-value: 0.569)
# Водопровод: -3422.9987 (p-value: 0.288)

# %%
df_panel   = pd.read_csv('единицы_без_протестов_2010t3.csv')
df_treated = pd.read_csv('протесты_2010t3.csv')


df_panel['group'] = 0   # Контрольные муниципалитеты
df_treated['group'] = 1   # Протестные муниципалитеты

# 3. Объединяем вертикально (concatenate)
df_panel = pd.concat([df_panel, df_treated], ignore_index=True)

df_panel = df_panel[['year', 'municipality', 'oktmo',
                     'Жилье (1000 м2)', 'Дороги (%)', 'Канализация (1 м)', 'Водопровод (1 метр)',
                     'region_name', 'group']].drop_duplicates(subset=['year','municipality','oktmo'])




# df_panel.to_csv('panel_all3.csv', index=False)
df_panel = df_panel[df_panel['year'].isin([2009, 2013])].reset_index(drop=True)
df_panel['post'] = (df_panel['year'] == 2013).astype(int)

df_panel = df_panel.rename(columns={
    'Жилье (1000 м2)': 'Жилье',
    'Дороги (%)': 'Дороги',
    'Канализация (1 м)': 'Канализация',
    'Водопровод (1 метр)': 'Водопровод'
})



def run_did(data, outcome):
    # Удаляем строки с пропусками по outcome
    d = data.dropna(subset=[outcome, 'group', 'post']).copy()
    formula = f'{outcome} ~ group + post + group:post + C(region_name)'
    model = smf.ols(formula, data=d).fit(cov_type='HC1')
    return model

outcomes = ['Жилье', 'Дороги', 'Канализация', 'Водопровод']
results = {o: run_did(df_panel, o) for o in outcomes}

print("\nКоэффициенты взаимодействия (group:post) и p-value:")
coef_rows = []
for o, m in results.items():
    coef = m.params.get('group:post', 0)
    pval = m.pvalues.get('group:post', 1)
    coef_rows.append([o, coef, pval])
    print(f"{o}: {coef:.4f} (p-value: {pval:.3f})")
    # print(m.summary())
# Out:
# Коэффициенты взаимодействия (group:post) и p-value:
# Жилье: 50.9519 (p-value: 0.405)
# Дороги: 23.5417 (p-value: 0.000)
# Канализация: -358.1879 (p-value: 0.302)
# Водопровод: -4097.3927 (p-value: 0.132)

# %%
datasets = ['2010t.csv', '2010tM.csv', '2010tM2.csv', '2010t+.csv']

# Годы для анализа
years_combinations = [
    [2008, 2011],
    [2008, 2012],
    [2008, 2013]
]

for dataset in datasets:
    print(f"\n{dataset}")
    print("=" * 50)
    
    # Загрузка данных
    df = pd.read_csv(dataset)
    
    # Подготовка данных
    protest = df[[
        'year', 
        'municipality_protest', 
        'oktmo_protest', 
        'Жилье (1000 м2)_protest', 
        'Дороги (%)_protest', 
        'Канализация (1 м)_protest', 
        'Водопровод (1 метр)_protest',
        'region_name_protest',
    ]]

    protest.columns = [
        'year', 
        'municipality', 
        'oktmo', 
        'Жилье', 
        'Дороги', 
        'Канализация', 
        'Водопровод',
        'region_name',
    ]
    protest['group'] = 1  

    event = df[[
        'year', 
        'municipality_event', 
        'oktmo_event',
        'Жилье (1000 м2)_event', 
        'Дороги (%)_event', 
        'Канализация (1 м)_event', 
        'Водопровод (1 метр)_event',
        'region_name_event',
    ]]
    event.columns = [
        'year', 
        'municipality', 
        'oktmo', 
        'Жилье', 
        'Дороги', 
        'Канализация', 
        'Водопровод',
        'region_name',
    ]
    event['group'] = 0  

    combined = pd.concat([protest, event], ignore_index=True)

    def run_did(data, outcome, years):
        data_filtered = data[data['year'].isin(years)].copy()
        data_filtered['post'] = (data_filtered['year'] == years[1]).astype(int)
        data_filtered = data_filtered.dropna(subset=[outcome, 'group', 'post'])
        
        formula = f'{outcome} ~ group + post + group:post + C(region_name) + C(year)'
        model = smf.ols(formula, data=data_filtered).fit(cov_type='HC1')
        return model

    for years in years_combinations:
        print(f"\nГоды: {years[0]} -- {years[1]}")
        
        results = {}
        for outcome in ['Жилье', 'Дороги', 'Канализация', 'Водопровод']:
            model = run_did(combined, outcome, years)
            results[outcome] = model

        print("Коэффициенты взаимодействия (group:post):")
        for outcome, model in results.items():
            coef = model.params.get('group:post', 0)
            pval = model.pvalues.get('group:post', 1)
            print(f"{outcome}: {coef:.2f} (p-value: {pval:.3f})")
# Out:
# 2010t.csv
# ==================================================
#
# Годы: 2008 -- 2011
# Коэффициенты взаимодействия (group:post):
# Жилье: -1.25 (p-value: 0.995)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Жилье   R-squared:                       0.349
# Model:                            OLS   Adj. R-squared:                  0.153
# Method:                 Least Squares   F-statistic:                     3.166
# Date:                Mon, 15 Sep 2025   Prob (F-statistic):           1.05e-09
# Time:                        15:28:10   Log-Likelihood:                -2050.7
# No. Observations:                 256   AIC:                             4221.
# Df Residuals:                     196   BIC:                             4434.
# Df Model:                          59
# Covariance Type:                  HC1
# ==========================================================================================================
#                                              coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                               -114.2261    206.015     -0.554      0.579    -518.009     289.557
# C(region_name)[T.Алтайский]               35.6693    224.661      0.159      0.874    -404.659     475.997
# C(region_name)[T.Амурская]                -6.3000    101.524     -0.062      0.951    -205.284     192.684
# C(region_name)[T.Архангельская]          133.9379    107.272      1.249      0.212     -76.311     344.187
# C(region_name)[T.Астраханская]            38.3096    135.014      0.284      0.777    -226.313     302.933
# C(region_name)[T.Башкортостан]           -47.3500     88.588     -0.534      0.593    -220.978     126.278
# C(region_name)[T.Белгородская]           107.8743    231.001      0.467      0.641    -344.879     560.628
# C(region_name)[T.Брянская]                38.8896    128.643      0.302      0.762    -213.246     291.025
# C(region_name)[T.Владимирская]            64.7026    218.294      0.296      0.767    -363.146     492.551
# C(region_name)[T.Волгоградская]           22.3193    226.543      0.099      0.922    -421.698     466.336
# C(region_name)[T.Вологодская]            133.9298    100.148      1.337      0.181     -62.357     330.217
# C(region_name)[T.Воронежская]            165.3000    123.816      1.335      0.182     -77.376     407.976
# C(region_name)[T.Дагестан]               190.8731    133.782      1.427      0.154     -71.335     453.082
# C(region_name)[T.Ивановская]             -39.2000    103.079     -0.380      0.704    -241.230     162.830
# C(region_name)[T.Иркутская]              174.6628    179.048      0.976      0.329    -176.266     525.591
# C(region_name)[T.Калининградская]         21.4500    103.166      0.208      0.835    -180.751     223.651
# C(region_name)[T.Калужская]              128.0996    147.722      0.867      0.386    -161.430     417.629
# C(region_name)[T.Камчатский]              44.3500     89.958      0.493      0.622    -131.965     220.665
# C(region_name)[T.Карачаево-Черкесская]   -31.2550    103.261     -0.303      0.762    -233.644     171.134
# C(region_name)[T.Карелия]                 78.9693    221.656      0.356      0.722    -355.469     513.407
# C(region_name)[T.Кемеровская]             54.4693    226.557      0.240      0.810    -389.574     498.513
# C(region_name)[T.Кировская]               22.6193    226.624      0.100      0.920    -421.556     466.795
# C(region_name)[T.Краснодарский]           10.1348     94.548      0.107      0.915    -175.176     195.446
# C(region_name)[T.Красноярский]            25.1193    226.409      0.111      0.912    -418.635     468.873
# C(region_name)[T.Курганская]              -8.6000    102.558     -0.084      0.933    -209.610     192.410
# C(region_name)[T.Ленинградская]           42.1567     78.366      0.538      0.591    -111.438     195.751
# C(region_name)[T.Марий]                   86.4668    220.011      0.393      0.694    -344.747     517.681
# C(region_name)[T.Московская]              41.5991    110.208      0.377      0.706    -174.405     257.603
# C(region_name)[T.Мурманская]             -49.4000    103.777     -0.476      0.634    -252.798     153.998
# C(region_name)[T.Нижегородская]           35.3693    220.225      0.161      0.872    -396.265     467.003
# C(region_name)[T.Новосибирская]           30.3018    216.931      0.140      0.889    -394.875     455.478
# C(region_name)[T.Омская]                  86.5628    164.791      0.525      0.599    -236.421     409.547
# C(region_name)[T.Оренбургская]            86.8471    134.020      0.648      0.517    -175.827     349.521
# C(region_name)[T.Орловская]               49.9500    102.183      0.489      0.625    -150.326     250.226
# C(region_name)[T.Пермский]                16.8412    158.878      0.106      0.916    -294.554     328.237
# C(region_name)[T.Приморский]              73.8193    221.755      0.333      0.739    -360.813     508.451
# C(region_name)[T.Ростовская]             -38.0500    103.340     -0.368      0.713    -240.592     164.492
# C(region_name)[T.Рязанская]              848.8500    804.047      1.056      0.291    -727.053    2424.753
# C(region_name)[T.Самарская]              -41.5500     88.953     -0.467      0.640    -215.895     132.795
# C(region_name)[T.Саратовская]              9.6346    136.945      0.070      0.944    -258.773     278.042
# C(region_name)[T.Саха]                    95.8543    252.616      0.379      0.704    -399.265     590.973
# C(region_name)[T.Сахалинская]            -19.0500    100.983     -0.189      0.850    -216.972     178.872
# C(region_name)[T.Северная]                28.5693    227.265      0.126      0.900    -416.862     474.001
# C(region_name)[T.Смоленская]              41.8943    222.322      0.188      0.851    -393.848     477.637
# C(region_name)[T.Ставропольский]          12.5894    171.989      0.073      0.942    -324.502     349.681
# C(region_name)[T.Тамбовская]             107.5795    165.577      0.650      0.516    -216.945     432.104
# C(region_name)[T.Татарстан]              248.1000     74.189      3.344      0.001     102.692     393.508
# C(region_name)[T.Тверская]                55.9846    134.289      0.417      0.677    -207.217     319.187
# C(region_name)[T.Тульская]               102.5471    133.872      0.766      0.444    -159.838     364.932
# C(region_name)[T.Тыва]                    38.9543    226.213      0.172      0.863    -404.416     482.324
# C(region_name)[T.Тюменская]               74.8193    225.618      0.332      0.740    -367.384     517.022
# C(region_name)[T.Удмуртская]              -7.6654    135.280     -0.057      0.955    -272.809     257.478
# C(region_name)[T.Ульяновская]             32.0628    167.732      0.191      0.848    -296.686     360.812
# C(region_name)[T.Хабаровский]             69.4000    101.868      0.681      0.496    -130.257     269.057
# C(region_name)[T.Хакасия]               3028.9909   1647.073      1.839      0.066    -199.213    6257.195
# C(region_name)[T.Челябинская]             56.5068    217.090      0.260      0.795    -368.982     481.995
# C(region_name)[T.Ярославская]            113.1250    126.797      0.892      0.372    -135.392     361.642
# C(year)[T.2011.0]                         92.6069     69.495      1.333      0.183     -43.601     228.815
# group                                     72.3925    178.467      0.406      0.685    -277.397     422.182
# post                                      92.6069     69.495      1.333      0.183     -43.601     228.815
# group:post                                -1.2466    208.301     -0.006      0.995    -409.508     407.015
# ==============================================================================
# Omnibus:                      333.890   Durbin-Watson:                   2.473
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            44606.307
# Skew:                           5.559   Prob(JB):                         0.00
# Kurtosis:                      66.704   Cond. No.                     2.25e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# [2] The smallest eigenvalue is 1.06e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Дороги: 12.58 (p-value: 0.014)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Дороги   R-squared:                       0.444
# Model:                            OLS   Adj. R-squared:                  0.277
# Method:                 Least Squares   F-statistic:                     4.159
# Date:                Mon, 15 Sep 2025   Prob (F-statistic):           3.41e-14
# Time:                        15:28:10   Log-Likelihood:                -1102.4
# No. Observations:                 256   AIC:                             2325.
# Df Residuals:                     196   BIC:                             2537.
# Df Model:                          59
# Covariance Type:                  HC1
# ==========================================================================================================
#                                              coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                -13.9284      9.888     -1.409      0.159     -33.309       5.452
# C(region_name)[T.Алтайский]               29.9594     16.232      1.846      0.065      -1.855      61.774
# C(region_name)[T.Амурская]              4.618e-14     12.787   3.61e-15      1.000     -25.062      25.062
# C(region_name)[T.Архангельская]            3.6799      9.699      0.379      0.704     -15.330      22.690
# C(region_name)[T.Астраханская]            49.3972     20.991      2.353      0.019       8.255      90.539
# C(region_name)[T.Башкортостан]          9.319e-14     11.074   8.42e-15      1.000     -21.704      21.704
# C(region_name)[T.Белгородская]            56.3494     35.649      1.581      0.114     -13.521     126.220
# C(region_name)[T.Брянская]                23.9147     15.299      1.563      0.118      -6.070      53.900
# C(region_name)[T.Владимирская]            24.6761     11.913      2.071      0.038       1.326      48.026
# C(region_name)[T.Волгоградская]            9.0294     10.551      0.856      0.392     -11.650      29.709
# C(region_name)[T.Вологодская]              2.2573     10.082      0.224      0.823     -17.503      22.018
# C(region_name)[T.Воронежская]           8.555e-14     12.787   6.69e-15      1.000     -25.062      25.062
# C(region_name)[T.Дагестан]                 3.0098     10.372      0.290      0.772     -17.320      23.339
# C(region_name)[T.Ивановская]            1.769e-14     12.787   1.38e-15      1.000     -25.062      25.062
# C(region_name)[T.Иркутская]               22.6863     17.495      1.297      0.195     -11.603      56.976
# C(region_name)[T.Калининградская]          1.5350     13.692      0.112      0.911     -25.301      28.371
# C(region_name)[T.Калужская]               36.2622     14.372      2.523      0.012       8.094      64.430
# C(region_name)[T.Камчатский]             3.61e-14     12.787   2.82e-15      1.000     -25.062      25.062
# C(region_name)[T.Карачаево-Черкесская]    10.6000      9.054      1.171      0.242      -7.146      28.346
# C(region_name)[T.Карелия]                  9.0294     10.551      0.856      0.392     -11.650      29.709
# C(region_name)[T.Кемеровская]             11.0694     11.274      0.982      0.326     -11.026      33.165
# C(region_name)[T.Кировская]                9.0294     10.551      0.856      0.392     -11.650      29.709
# C(region_name)[T.Краснодарский]            7.3371     10.441      0.703      0.482     -13.127      27.801
# C(region_name)[T.Красноярский]             9.0294     10.551      0.856      0.392     -11.650      29.709
# C(region_name)[T.Курганская]              45.7450     29.353      1.558      0.119     -11.786     103.276
# C(region_name)[T.Ленинградская]           14.4183     11.701      1.232      0.218      -8.516      37.353
# C(region_name)[T.Марий]                   13.9769     10.566      1.323      0.186      -6.731      34.685
# C(region_name)[T.Московская]              31.5629     12.339      2.558      0.011       7.378      55.748
# C(region_name)[T.Мурманская]           -8.162e-16     12.787  -6.38e-17      1.000     -25.062      25.062
# C(region_name)[T.Нижегородская]           34.0294     25.214      1.350      0.177     -15.389      83.448
# C(region_name)[T.Новосибирская]            9.0294      9.978      0.905      0.366     -10.528      28.586
# C(region_name)[T.Омская]                  22.7096     12.425      1.828      0.068      -1.642      47.062
# C(region_name)[T.Оренбургская]             4.5147     10.828      0.417      0.677     -16.708      25.737
# C(region_name)[T.Орловская]            -1.393e-14     12.787  -1.09e-15      1.000     -25.062      25.062
# C(region_name)[T.Пермский]                51.8996     17.850      2.908      0.004      16.915      86.884
# C(region_name)[T.Приморский]              10.5794     10.044      1.053      0.292      -9.106      30.265
# C(region_name)[T.Ростовская]              35.8150     18.885      1.896      0.058      -1.199      72.829
# C(region_name)[T.Рязанская]             1.526e-14     12.787   1.19e-15      1.000     -25.062      25.062
# C(region_name)[T.Самарская]               16.8750     16.682      1.012      0.312     -15.821      49.571
# C(region_name)[T.Саратовская]             17.9397     11.487      1.562      0.118      -4.574      40.454
# C(region_name)[T.Саха]                     9.0294     10.551      0.856      0.392     -11.650      29.709
# C(region_name)[T.Сахалинская]             39.3150     24.462      1.607      0.108      -8.630      87.260
# C(region_name)[T.Северная]                 9.0294     10.551      0.856      0.392     -11.650      29.709
# C(region_name)[T.Смоленская]              17.8194     12.290      1.450      0.147      -6.269      41.908
# C(region_name)[T.Ставропольский]           6.9808     10.109      0.691      0.490     -12.833      26.794
# C(region_name)[T.Тамбовская]              10.5896     11.083      0.956      0.339     -11.132      32.311
# C(region_name)[T.Татарстан]                2.0000     13.977      0.143      0.886     -25.394      29.394
# C(region_name)[T.Тверская]                 4.5147     10.828      0.417      0.677     -16.708      25.737
# C(region_name)[T.Тульская]                 4.5147     10.087      0.448      0.654     -15.255      24.284
# C(region_name)[T.Тыва]                     9.0294     10.551      0.856      0.392     -11.650      29.709
# C(region_name)[T.Тюменская]                9.0294     10.551      0.856      0.392     -11.650      29.709
# C(region_name)[T.Удмуртская]              17.1822      9.927      1.731      0.083      -2.274      36.638
# C(region_name)[T.Ульяновская]              6.6229     10.398      0.637      0.524     -13.756      27.002
# C(region_name)[T.Хабаровский]          -3.496e-14     12.787  -2.73e-15      1.000     -25.062      25.062
# C(region_name)[T.Хакасия]                  4.5147     10.087      0.448      0.654     -15.255      24.284
# C(region_name)[T.Челябинская]              9.0294      9.978      0.905      0.366     -10.528      28.586
# C(region_name)[T.Ярославская]          -9.066e-15     11.074  -8.19e-16      1.000     -21.704      21.704
# C(year)[T.2011.0]                          4.8991      1.598      3.067      0.002       1.768       8.030
# group                                      2.7399      3.654      0.750      0.453      -4.421       9.901
# post                                       4.8991      1.598      3.067      0.002       1.768       8.030
# group:post                                12.5789      5.127      2.453      0.014       2.530      22.628
# ==============================================================================
# Omnibus:                       60.887   Durbin-Watson:                   2.278
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              142.107
# Skew:                           1.118   Prob(JB):                     1.39e-31
# Kurtosis:                       5.884   Cond. No.                     2.25e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# [2] The smallest eigenvalue is 1.06e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Канализация: -101.58 (p-value: 0.809)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Канализация   R-squared:                       0.386
# Model:                            OLS   Adj. R-squared:                  0.201
# Method:                 Least Squares   F-statistic:                     5.321
# Date:                Mon, 15 Sep 2025   Prob (F-statistic):           4.22e-19
# Time:                        15:28:10   Log-Likelihood:                -2230.2
# No. Observations:                 256   AIC:                             4580.
# Df Residuals:                     196   BIC:                             4793.
# Df Model:                          59
# Covariance Type:                  HC1
# ==========================================================================================================
#                                              coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                               -736.8314    278.153     -2.649      0.008   -1282.001    -191.662
# C(region_name)[T.Алтайский]              806.6689    266.122      3.031      0.002     285.080    1328.258
# C(region_name)[T.Амурская]               434.5000    412.175      1.054      0.292    -373.348    1242.348
# C(region_name)[T.Архангельская]          882.8238    387.806      2.276      0.023     122.737    1642.910
# C(region_name)[T.Астраханская]           578.3345    233.984      2.472      0.013     119.735    1036.934
# C(region_name)[T.Башкортостан]           200.0000    153.025      1.307      0.191     -99.924     499.924
# C(region_name)[T.Белгородская]           931.6689    288.718      3.227      0.001     365.792    1497.546
# C(region_name)[T.Брянская]              1052.0845    329.697      3.191      0.001     405.890    1698.279
# C(region_name)[T.Владимирская]          1340.0023    361.919      3.702      0.000     630.654    2049.350
# C(region_name)[T.Волгоградская]          756.6689    260.562      2.904      0.004     245.977    1267.361
# C(region_name)[T.Вологодская]            378.8172    196.215      1.931      0.054      -5.758     763.392
# C(region_name)[T.Воронежская]           1750.0000    954.785      1.833      0.067    -121.344    3621.344
# C(region_name)[T.Дагестан]              1293.3896    724.488      1.785      0.074    -126.581    2713.361
# C(region_name)[T.Ивановская]             224.0000     67.838      3.302      0.001      91.039     356.961
# C(region_name)[T.Иркутская]              571.1126    222.592      2.566      0.010     134.840    1007.385
# C(region_name)[T.Калининградская]        375.0000    130.794      2.867      0.004     118.648     631.352
# C(region_name)[T.Калужская]             1468.3345    432.794      3.393      0.001     620.074    2316.595
# C(region_name)[T.Камчатский]            2.626e-12     80.716   3.25e-14      1.000    -158.201     158.201
# C(region_name)[T.Карачаево-Черкесская]  4450.0000   3007.262      1.480      0.139   -1444.125    1.03e+04
# C(region_name)[T.Карелия]               1032.1689    263.930      3.911      0.000     514.876    1549.462
# C(region_name)[T.Кемеровская]            956.6689    298.049      3.210      0.001     372.505    1540.833
# C(region_name)[T.Кировская]             1306.6689    266.122      4.910      0.000     785.080    1828.258
# C(region_name)[T.Краснодарский]          944.9552    345.995      2.731      0.006     266.818    1623.093
# C(region_name)[T.Красноярский]           756.6689    260.562      2.904      0.004     245.977    1267.361
# C(region_name)[T.Курганская]            1.493e-11     80.716   1.85e-13      1.000    -158.201     158.201
# C(region_name)[T.Ленинградская]          577.8333    260.530      2.218      0.027      67.204    1088.463
# C(region_name)[T.Марий]                  847.1689    264.619      3.201      0.001     328.525    1365.813
# C(region_name)[T.Московская]             698.9758    228.227      3.063      0.002     251.659    1146.293
# C(region_name)[T.Мурманская]              81.5000    135.540      0.601      0.548    -184.153     347.153
# C(region_name)[T.Нижегородская]         1166.6689    350.143      3.332      0.001     480.401    1852.937
# C(region_name)[T.Новосибирская]         1098.5439    434.505      2.528      0.011     246.929    1950.159
# C(region_name)[T.Омская]                2137.7793    970.398      2.203      0.028     235.835    4039.724
# C(region_name)[T.Оренбургская]          5896.9595   3071.757      1.920      0.055    -123.574    1.19e+04
# C(region_name)[T.Орловская]             1263.0000    197.237      6.403      0.000     876.422    1649.578
# C(region_name)[T.Пермский]               559.4460    251.801      2.222      0.026      65.924    1052.968
# C(region_name)[T.Приморский]             952.1689    265.877      3.581      0.000     431.060    1473.278
# C(region_name)[T.Ростовская]            5.355e-12     80.716   6.63e-14      1.000    -158.201     158.201
# C(region_name)[T.Рязанская]             5520.0000   4518.269      1.222      0.222   -3335.645    1.44e+04
# C(region_name)[T.Самарская]             1114.5000    611.224      1.823      0.068     -83.477    2312.477
# C(region_name)[T.Саратовская]            628.3345    251.322      2.500      0.012     135.753    1120.916
# C(region_name)[T.Саха]                   947.6689    269.865      3.512      0.000     418.743    1476.595
# C(region_name)[T.Сахалинская]            100.0000     80.716      1.239      0.215     -58.201     258.201
# C(region_name)[T.Северная]               756.6689    260.562      2.904      0.004     245.977    1267.361
# C(region_name)[T.Смоленская]             894.9189    266.631      3.356      0.001     372.331    1417.507
# C(region_name)[T.Ставропольский]        1463.7517    659.652      2.219      0.026     170.858    2756.646
# C(region_name)[T.Тамбовская]             521.1126    241.008      2.162      0.031      48.745     993.480
# C(region_name)[T.Татарстан]             1800.0000    914.454      1.968      0.049       7.702    3592.298
# C(region_name)[T.Тверская]               379.8345    259.557      1.463      0.143    -128.887     888.556
# C(region_name)[T.Тульская]               694.7095    284.291      2.444      0.015     137.510    1251.909
# C(region_name)[T.Тыва]                   756.6689    260.562      2.904      0.004     245.977    1267.361
# C(region_name)[T.Тюменская]              756.6689    260.562      2.904      0.004     245.977    1267.361
# C(region_name)[T.Удмуртская]             947.5845    456.529      2.076      0.038      52.804    1842.365
# C(region_name)[T.Ульяновская]            721.1126    331.786      2.173      0.030      70.824    1371.402
# C(region_name)[T.Хабаровский]           6.951e-12     80.716   8.61e-14      1.000    -158.201     158.201
# C(region_name)[T.Хакасия]                590.3345    261.212      2.260      0.024      78.369    1102.300
# C(region_name)[T.Челябинская]           1309.6689    375.504      3.488      0.000     573.694    2045.644
# C(region_name)[T.Ярославская]           5861.2500   3928.239      1.492      0.136   -1837.957    1.36e+04
# C(year)[T.2011.0]                        -19.8375     90.113     -0.220      0.826    -196.455     156.780
# group                                    807.4580    321.628      2.511      0.012     177.079    1437.837
# post                                     -19.8375     90.113     -0.220      0.826    -196.455     156.780
# group:post                              -101.5781    419.913     -0.242      0.809    -924.592     721.436
# ==============================================================================
# Omnibus:                      141.878   Durbin-Watson:                   1.731
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3454.577
# Skew:                           1.655   Prob(JB):                         0.00
# Kurtosis:                      20.689   Cond. No.                     2.25e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# [2] The smallest eigenvalue is 1.06e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Водопровод: -2299.42 (p-value: 0.432)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Водопровод   R-squared:                       0.295
# Model:                            OLS   Adj. R-squared:                  0.083
# Method:                 Least Squares   F-statistic:                     13.66
# Date:                Mon, 15 Sep 2025   Prob (F-statistic):           1.34e-44
# Time:                        15:28:10   Log-Likelihood:                -2727.0
# No. Observations:                 256   AIC:                             5574.
# Df Residuals:                     196   BIC:                             5787.
# Df Model:                          59
# Covariance Type:                  HC1
# ==========================================================================================================
#                                              coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                              -1593.8848   2779.631     -0.573      0.566   -7041.862    3854.092
# C(region_name)[T.Алтайский]             4506.7208   3242.421      1.390      0.165   -1848.308    1.09e+04
# C(region_name)[T.Амурская]              -470.0000   1288.740     -0.365      0.715   -2995.885    2055.885
# C(region_name)[T.Архангельская]         1676.0642   1348.407      1.243      0.214    -966.766    4318.894
# C(region_name)[T.Астраханская]          1.379e+04   3259.265      4.232      0.000    7405.319    2.02e+04
# C(region_name)[T.Башкортостан]          4975.0000   1718.157      2.896      0.004    1607.474    8342.526
# C(region_name)[T.Белгородская]          1746.7208   2775.265      0.629      0.529   -3692.698    7186.140
# C(region_name)[T.Брянская]              2.714e+04   2.03e+04      1.338      0.181   -1.26e+04    6.69e+04
# C(region_name)[T.Владимирская]          3240.0541   2815.263      1.151      0.250   -2277.761    8757.869
# C(region_name)[T.Волгоградская]         1706.7208   2770.688      0.616      0.538   -3723.727    7137.169
# C(region_name)[T.Вологодская]           1757.8677   1277.836      1.376      0.169    -746.646    4262.381
# C(region_name)[T.Воронежская]           9000.0000   4208.441      2.139      0.032     751.607    1.72e+04
# C(region_name)[T.Дагестан]              3930.4069   2308.054      1.703      0.089    -593.295    8454.109
# C(region_name)[T.Ивановская]              61.0000   1306.806      0.047      0.963   -2500.292    2622.292
# C(region_name)[T.Иркутская]             2545.3139   2114.874      1.204      0.229   -1599.762    6690.390
# C(region_name)[T.Калининградская]       8775.0000   3035.385      2.891      0.004    2825.755    1.47e+04
# C(region_name)[T.Калужская]             3564.3604   2362.342      1.509      0.131   -1065.745    8194.466
# C(region_name)[T.Камчатский]            -150.0000   1007.474     -0.149      0.882   -2124.612    1824.612
# C(region_name)[T.Карачаево-Черкесская]  3.327e+04   2.35e+04      1.417      0.157   -1.28e+04    7.93e+04
# C(region_name)[T.Карелия]               3506.7208   2770.082      1.266      0.206   -1922.541    8935.983
# C(region_name)[T.Кемеровская]           5056.7208   3351.960      1.509      0.131   -1513.000    1.16e+04
# C(region_name)[T.Кировская]             4006.7208   2789.211      1.437      0.151   -1460.032    9473.474
# C(region_name)[T.Краснодарский]         1.238e+04   2913.717      4.248      0.000    6665.461    1.81e+04
# C(region_name)[T.Красноярский]          1656.7208   2771.404      0.598      0.550   -3775.132    7088.573
# C(region_name)[T.Курганская]             250.0000   1421.537      0.176      0.860   -2536.161    3036.161
# C(region_name)[T.Ленинградская]         3095.3333   2335.067      1.326      0.185   -1481.314    7671.981
# C(region_name)[T.Марий]                 2056.2208   2794.580      0.736      0.462   -3421.055    7533.497
# C(region_name)[T.Московская]            2204.5203   1460.671      1.509      0.131    -658.342    5067.383
# C(region_name)[T.Мурманская]            -564.5000   1286.137     -0.439      0.661   -3085.283    1956.283
# C(region_name)[T.Нижегородская]         4053.4708   3003.928      1.349      0.177   -1834.121    9941.062
# C(region_name)[T.Новосибирская]         5510.3458   3220.031      1.711      0.087    -800.799    1.18e+04
# C(region_name)[T.Омская]                4678.1472   2870.745      1.630      0.103    -948.410    1.03e+04
# C(region_name)[T.Оренбургская]           1.05e+04   5091.789      2.061      0.039     516.886    2.05e+04
# C(region_name)[T.Орловская]             4157.5000   2638.857      1.575      0.115   -1014.564    9329.564
# C(region_name)[T.Пермский]              4525.6472   2256.016      2.006      0.045     103.937    8947.357
# C(region_name)[T.Приморский]            4329.4708   2795.085      1.549      0.121   -1148.796    9807.737
# C(region_name)[T.Ростовская]            3750.0000   1229.321      3.050      0.002    1340.576    6159.424
# C(region_name)[T.Рязанская]              650.0000   1421.537      0.457      0.647   -2136.161    3436.161
# C(region_name)[T.Самарская]             4765.5000   1787.415      2.666      0.008    1262.231    8268.769
# C(region_name)[T.Саратовская]           3103.3604   1719.726      1.805      0.071    -267.240    6473.961
# C(region_name)[T.Саха]                  2056.7208   2816.651      0.730      0.465   -3463.814    7577.256
# C(region_name)[T.Сахалинская]           1000.0000    928.599      1.077      0.282    -820.021    2820.021
# C(region_name)[T.Северная]              3.831e+04   1.32e+04      2.899      0.004    1.24e+04    6.42e+04
# C(region_name)[T.Смоленская]            4681.7208   3231.606      1.449      0.147   -1652.111     1.1e+04
# C(region_name)[T.Ставропольский]        9063.7906   5014.754      1.807      0.071    -764.946    1.89e+04
# C(region_name)[T.Тамбовская]            2542.9805   2519.421      1.009      0.313   -2394.995    7480.956
# C(region_name)[T.Татарстан]             7250.0000   1485.013      4.882      0.000    4339.428    1.02e+04
# C(region_name)[T.Тверская]               890.3604   1833.476      0.486      0.627   -2703.186    4483.907
# C(region_name)[T.Тульская]              6313.2166   2061.007      3.063      0.002    2273.716    1.04e+04
# C(region_name)[T.Тыва]                  1506.7208   2770.082      0.544      0.586   -3922.541    6935.983
# C(region_name)[T.Тюменская]             5858.7208   3399.088      1.724      0.085    -803.369    1.25e+04
# C(region_name)[T.Удмуртская]            6848.6104   3620.104      1.892      0.059    -246.662    1.39e+04
# C(region_name)[T.Ульяновская]           2521.1472   2447.651      1.030      0.303   -2276.161    7318.456
# C(region_name)[T.Хабаровский]            6.52e-11   1215.684   5.36e-14      1.000   -2382.698    2382.698
# C(region_name)[T.Хакасия]               2964.2354   2098.583      1.412      0.158   -1148.912    7077.383
# C(region_name)[T.Челябинская]           1.013e+04   3981.895      2.544      0.011    2327.475    1.79e+04
# C(region_name)[T.Ярославская]           1.038e+04   6642.239      1.562      0.118   -2640.799    2.34e+04
# C(year)[T.2011.0]                         87.1641    604.549      0.144      0.885   -1097.730    1272.058
# group                                   3306.4329   3656.247      0.904      0.366   -3859.679    1.05e+04
# post                                      87.1641    604.549      0.144      0.885   -1097.730    1272.058
# group:post                             -2299.4242   2923.741     -0.786      0.432   -8029.852    3431.003
# ==============================================================================
# Omnibus:                      376.554   Durbin-Watson:                   2.184
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            73631.445
# Skew:                           6.820   Prob(JB):                         0.00
# Kurtosis:                      84.957   Cond. No.                     2.25e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# [2] The smallest eigenvalue is 1.06e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Годы: 2008 -- 2012
# Коэффициенты взаимодействия (group:post):
# Жилье: -25.48 (p-value: 0.436)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Жилье   R-squared:                       0.418
# Model:                            OLS   Adj. R-squared:                  0.240
# Method:                 Least Squares   F-statistic:                     27.89
# Date:                Mon, 15 Sep 2025   Prob (F-statistic):           1.00e-68
# Time:                        15:28:11   Log-Likelihood:                -1562.8
# No. Observations:                 254   AIC:                             3246.
# Df Residuals:                     194   BIC:                             3458.
# Df Model:                          59
# Covariance Type:                  HC1
# ==========================================================================================================
#                                              coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                -14.8086     21.583     -0.686      0.493     -57.110      27.493
# C(region_name)[T.Алтайский]               24.8327     21.429      1.159      0.247     -17.168      66.833
# C(region_name)[T.Амурская]                -4.7000     12.748     -0.369      0.712     -29.686      20.286
# C(region_name)[T.Архангельская]          137.9305     64.846      2.127      0.033      10.835     265.026
# C(region_name)[T.Астраханская]            30.7413     17.862      1.721      0.085      -4.267      65.750
# C(region_name)[T.Башкортостан]           -45.6000     10.302     -4.426      0.000     -65.791     -25.409
# C(region_name)[T.Белгородская]            94.2877     28.271      3.335      0.001      38.877     149.699
# C(region_name)[T.Брянская]                20.3713     16.831      1.210      0.226     -12.616      53.359
# C(region_name)[T.Владимирская]            54.0660     23.703      2.281      0.023       7.608     100.524
# C(region_name)[T.Волгоградская]           11.6827     21.644      0.540      0.589     -30.738      54.104
# C(region_name)[T.Вологодская]            136.4457     37.567      3.632      0.000      62.816     210.075
# C(region_name)[T.Воронежская]            153.5000     31.458      4.880      0.000      91.844     215.156
# C(region_name)[T.Дагестан]               104.7506     85.019      1.232      0.218     -61.883     271.384
# C(region_name)[T.Ивановская]             -37.5000     11.242     -3.336      0.001     -59.535     -15.465
# C(region_name)[T.Иркутская]              182.5385     82.394      2.215      0.027      21.049     344.028
# C(region_name)[T.Калининградская]         22.3500     10.742      2.081      0.037       1.295      43.405
# C(region_name)[T.Калужская]              123.4063    107.318      1.150      0.250     -86.933     333.746
# C(region_name)[T.Камчатский]              45.9000     28.447      1.614      0.107      -9.855     101.655
# C(region_name)[T.Карачаево-Черкесская]   -29.5050     11.100     -2.658      0.008     -51.260      -7.750
# C(region_name)[T.Карелия]                 69.1827     25.154      2.750      0.006      19.882     118.483
# C(region_name)[T.Кемеровская]             42.5827     21.846      1.949      0.051      -0.235      85.401
# C(region_name)[T.Кировская]               13.8327     21.467      0.644      0.519     -28.242      55.908
# C(region_name)[T.Краснодарский]            8.8185     19.929      0.442      0.658     -30.242      47.879
# C(region_name)[T.Красноярский]            13.0827     21.779      0.601      0.548     -29.603      55.768
# C(region_name)[T.Курганская]              -6.7500     11.829     -0.571      0.568     -29.934      16.434
# C(region_name)[T.Ленинградская]           -4.9267     14.633     -0.337      0.736     -33.606      23.753
# C(region_name)[T.Марий]                   91.9302     68.613      1.340      0.180     -42.549     226.410
# C(region_name)[T.Московская]              53.5166     33.553      1.595      0.111     -12.246     119.279
# C(region_name)[T.Мурманская]             -47.6500     10.641     -4.478      0.000     -68.506     -26.794
# C(region_name)[T.Нижегородская]           24.5077     22.702      1.080      0.280     -19.988      69.003
# C(region_name)[T.Новосибирская]           19.6027     21.893      0.895      0.371     -23.307      62.513
# C(region_name)[T.Омская]                  80.0885     47.112      1.700      0.089     -12.250     172.427
# C(region_name)[T.Оренбургская]            74.6838     48.039      1.555      0.120     -19.472     168.839
# C(region_name)[T.Орловская]               51.7000     12.148      4.256      0.000      27.890      75.510
# C(region_name)[T.Пермский]                10.1835     21.708      0.469      0.639     -32.363      52.730
# C(region_name)[T.Приморский]              56.8577     28.840      1.971      0.049       0.333     113.383
# C(region_name)[T.Ростовская]             -36.3000     11.028     -3.292      0.001     -57.915     -14.685
# C(region_name)[T.Рязанская]              850.6000    720.216      1.181      0.238    -560.998    2262.198
# C(region_name)[T.Самарская]              -39.4500     10.894     -3.621      0.000     -60.802     -18.098
# C(region_name)[T.Саратовская]              5.1163     23.889      0.214      0.830     -41.705      51.937
# C(region_name)[T.Саха]                   172.7177     22.658      7.623      0.000     128.309     217.126
# C(region_name)[T.Сахалинская]            -26.0000      9.044     -2.875      0.004     -43.726      -8.274
# C(region_name)[T.Северная]                17.9327     22.108      0.811      0.417     -25.398      61.263
# C(region_name)[T.Смоленская]              42.6580     27.920      1.528      0.127     -12.064      97.380
# C(region_name)[T.Ставропольский]           4.5745     21.921      0.209      0.835     -38.390      47.539
# C(region_name)[T.Тамбовская]              98.9218     54.212      1.825      0.068      -7.332     205.176
# C(region_name)[T.Татарстан]              245.9500     97.581      2.520      0.012      54.696     437.204
# C(region_name)[T.Тверская]                50.7663     17.593      2.886      0.004      16.286      85.247
# C(region_name)[T.Тульская]                99.0788     56.105      1.766      0.077     -10.886     209.043
# C(region_name)[T.Тыва]                    27.7827     21.555      1.289      0.197     -14.465      70.030
# C(region_name)[T.Тюменская]               64.1827     21.348      3.007      0.003      22.341     106.024
# C(region_name)[T.Удмуртская]             -11.1337     22.409     -0.497      0.619     -55.055      32.787
# C(region_name)[T.Ульяновская]             69.8051     58.497      1.193      0.233     -44.846     184.456
# C(region_name)[T.Хабаровский]             71.1500     12.475      5.703      0.000      46.699      95.601
# C(region_name)[T.Хакасия]                  0.0451     18.119      0.002      0.998     -35.467      35.557
# C(region_name)[T.Челябинская]             44.5077     22.712      1.960      0.050      -0.008      89.023
# C(region_name)[T.Ярославская]            120.3000     78.362      1.535      0.125     -33.287     273.887
# C(year)[T.2012.0]                          3.8259      6.394      0.598      0.550      -8.707      16.358
# group                                     72.1211     24.259      2.973      0.003      24.574     119.668
# post                                       3.8259      6.394      0.598      0.550      -8.707      16.358
# group:post                               -25.4768     32.736     -0.778      0.436     -89.637      38.684
# ==============================================================================
# Omnibus:                      104.022   Durbin-Watson:                   2.252
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8606.915
# Skew:                           0.564   Prob(JB):                         0.00
# Kurtosis:                      31.495   Cond. No.                     4.50e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# [2] The smallest eigenvalue is 2.63e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Дороги: 16.55 (p-value: 0.004)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Дороги   R-squared:                       0.518
# Model:                            OLS   Adj. R-squared:                  0.372
# Method:                 Least Squares   F-statistic:                     5.638
# Date:                Mon, 15 Sep 2025   Prob (F-statistic):           2.82e-20
# Time:                        15:28:11   Log-Likelihood:                -1118.2
# No. Observations:                 254   AIC:                             2356.
# Df Residuals:                     194   BIC:                             2569.
# Df Model:                          59
# Covariance Type:                  HC1
# ==========================================================================================================
#                                              coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                 28.3139     24.210      1.170      0.242     -19.137      75.765
# C(region_name)[T.Алтайский]              -17.5164     25.706     -0.681      0.496     -67.900      32.867
# C(region_name)[T.Амурская]                 1.0800     34.399      0.031      0.975     -66.341      68.501
# C(region_name)[T.Архангельская]          -44.8093     24.615     -1.820      0.069     -93.053       3.435
# C(region_name)[T.Астраханская]           -25.6307     24.082     -1.064      0.287     -72.831      21.570
# C(region_name)[T.Башкортостан]           -42.6750     25.399     -1.680      0.093     -92.456       7.106
# C(region_name)[T.Белгородская]             4.6036     35.970      0.128      0.898     -65.896      75.103
# C(region_name)[T.Брянская]               -18.6607     24.483     -0.762      0.446     -66.647      29.326
# C(region_name)[T.Владимирская]           -24.6164     24.778     -0.993      0.320     -73.180      23.947
# C(region_name)[T.Волгоградская]          -38.4464     25.528     -1.506      0.132     -88.481      11.588
# C(region_name)[T.Вологодская]            -44.1528     24.752     -1.784      0.074     -92.666       4.360
# C(region_name)[T.Воронежская]            -26.5900     24.000     -1.108      0.268     -73.630      20.450
# C(region_name)[T.Дагестан]               -40.4522     25.185     -1.606      0.108     -89.814       8.910
# C(region_name)[T.Ивановская]               0.8450     34.262      0.025      0.980     -66.308      67.998
# C(region_name)[T.Иркутская]              -41.6059     24.976     -1.666      0.096     -90.557       7.345
# C(region_name)[T.Калининградская]        -16.5550     25.189     -0.657      0.511     -65.924      32.814
# C(region_name)[T.Калужская]              -10.0157     25.643     -0.391      0.696     -60.274      40.243
# C(region_name)[T.Камчатский]             -47.9250     28.146     -1.703      0.089    -103.090       7.240
# C(region_name)[T.Карачаево-Черкесская]   -32.5400     24.008     -1.355      0.175     -79.594      14.514
# C(region_name)[T.Карелия]                -38.4464     25.528     -1.506      0.132     -88.481      11.588
# C(region_name)[T.Кемеровская]             11.6436     37.777      0.308      0.758     -62.399      85.686
# C(region_name)[T.Кировская]              -38.4464     25.528     -1.506      0.132     -88.481      11.588
# C(region_name)[T.Краснодарский]          -27.0986     25.168     -1.077      0.282     -76.426      22.229
# C(region_name)[T.Красноярский]           -38.4464     25.528     -1.506      0.132     -88.481      11.588
# C(region_name)[T.Курганская]             -47.9250     28.146     -1.703      0.089    -103.090       7.240
# C(region_name)[T.Ленинградская]          -19.0067     24.713     -0.769      0.442     -67.443      29.430
# C(region_name)[T.Марий]                  -29.9764     25.147     -1.192      0.233     -79.263      19.310
# C(region_name)[T.Московская]             -17.5511     24.752     -0.709      0.478     -66.064      30.962
# C(region_name)[T.Мурманская]             -47.9250     28.146     -1.703      0.089    -103.090       7.240
# C(region_name)[T.Нижегородская]          -31.9164     24.832     -1.285      0.199     -80.587      16.754
# C(region_name)[T.Новосибирская]          -26.1464     27.089     -0.965      0.334     -79.240      26.947
# C(region_name)[T.Омская]                 -26.0876     24.743     -1.054      0.292     -74.582      22.407
# C(region_name)[T.Оренбургская]           -43.1857     25.611     -1.686      0.092     -93.382       7.010
# C(region_name)[T.Орловская]              -47.9250     28.146     -1.703      0.089    -103.090       7.240
# C(region_name)[T.Пермский]                 9.3774     27.613      0.340      0.734     -44.743      63.498
# C(region_name)[T.Приморский]             -14.3614     26.490     -0.542      0.588     -66.280      37.557
# C(region_name)[T.Ростовская]             -13.2000     25.845     -0.511      0.610     -63.855      37.455
# C(region_name)[T.Рязанская]              -47.9250     28.146     -1.703      0.089    -103.090       7.240
# C(region_name)[T.Самарская]              -15.9175     25.468     -0.625      0.532     -65.834      33.999
# C(region_name)[T.Саратовская]             -8.7607     29.413     -0.298      0.766     -66.409      48.887
# C(region_name)[T.Саха]                   -38.4464     25.528     -1.506      0.132     -88.481      11.588
# ...
# C(region_name)[T.Рязанская]               43.5600     17.611      2.473      0.013       9.043      78.077
# C(region_name)[T.Самарская]               25.1150     10.789      2.328      0.020       3.969      46.261
# C(region_name)[T.Саратовская]             29.9925     14.101      2.127      0.033       2.355      57.630
# C(region_name)[T.Сахалинская]             27.6900     22.517      1.230      0.219     -16.442      71.822
# C(region_name)[T.Ставропольский]           6.1700     10.674      0.578      0.563     -14.751      27.091
# C(region_name)[T.Тамбовская]              37.3425     14.897      2.507      0.012       8.145      66.540
# C(region_name)[T.Тверская]                14.1550     12.946      1.093      0.274     -11.218      39.528
# C(region_name)[T.Тульская]                24.2363     12.421      1.951      0.051      -0.108      48.581
# C(region_name)[T.Удмуртская]              21.6675     11.691      1.853      0.064      -1.247      44.582
# C(region_name)[T.Ульяновская]             11.2363     13.603      0.826      0.409     -15.425      37.897
# C(region_name)[T.Хабаровский]           3.112e-14     12.975    2.4e-15      1.000     -25.431      25.431
# C(region_name)[T.Хакасия]                 20.5600     11.082      1.855      0.064      -1.160      42.280
# C(region_name)[T.Ярославская]            4.89e-14     12.975   3.77e-15      1.000     -25.431      25.431
# C(year)[T.2013]                           12.3723      2.010      6.156      0.000       8.433      16.311
# group                                     -1.7756      2.309     -0.769      0.442      -6.302       2.751
# post                                      12.3723      2.010      6.156      0.000       8.433      16.311
# group:post                                15.2083      5.753      2.644      0.008       3.933      26.483
# ==============================================================================
# Omnibus:                       15.382   Durbin-Watson:                   2.311
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.299
# Skew:                           0.563   Prob(JB):                     0.000289
# Kurtosis:                       3.330   Cond. No.                     2.77e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# [2] The smallest eigenvalue is 7.85e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Канализация: -39.67 (p-value: 0.927)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Канализация   R-squared:                       0.117
# Model:                            OLS   Adj. R-squared:                 -0.041
# Method:                 Least Squares   F-statistic:                     1.505
# Date:                Mon, 15 Sep 2025   Prob (F-statistic):             0.0301
# Time:                        15:28:15   Log-Likelihood:                -2510.5
# No. Observations:                 284   AIC:                             5109.
# Df Residuals:                     240   BIC:                             5270.
# Df Model:                          43
# Covariance Type:                  HC1
# ==========================================================================================================
#                                              coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                               -327.0972    201.622     -1.622      0.105    -722.270      68.075
# C(region_name)[T.Алтай]                 1.301e-12    229.367   5.67e-15      1.000    -449.551     449.551
# C(region_name)[T.Амурская]                45.7500    214.824      0.213      0.831    -375.298     466.798
# C(region_name)[T.Архангельская]          478.9063    268.846      1.781      0.075     -48.023    1005.836
# C(region_name)[T.Астраханская]           225.0000    244.777      0.919      0.358    -254.755     704.755
# C(region_name)[T.Башкортостан]           212.5000    206.733      1.028      0.304    -192.690     617.690
# C(region_name)[T.Брянская]               403.1250    286.962      1.405      0.160    -159.309     965.559
# C(region_name)[T.Вологодская]            664.7500    383.114      1.735      0.083     -86.139    1415.639
# C(region_name)[T.Воронежская]            775.0000    639.672      1.212      0.226    -478.734    2028.734
# C(region_name)[T.Дагестан]               266.2500    261.723      1.017      0.309    -246.719     779.219
# C(region_name)[T.Ивановская]             392.0000    331.965      1.181      0.238    -258.640    1042.640
# C(region_name)[T.Иркутская]              375.0000    194.745      1.926      0.054      -6.694     756.694
# C(region_name)[T.Калининградская]         87.0000    205.569      0.423      0.672    -315.908     489.908
# C(region_name)[T.Калужская]              682.5000    440.746      1.549      0.121    -181.347    1546.347
# C(region_name)[T.Камчатский]           -1.302e-13    229.367  -5.68e-16      1.000    -449.551     449.551
# C(region_name)[T.Карачаево-Черкесская]   200.0000    232.577      0.860      0.390    -255.843     655.843
# C(region_name)[T.Кировская]              530.0000    343.587      1.543      0.123    -143.418    1203.418
# C(region_name)[T.Коми]                  1.677e-12    229.367   7.31e-15      1.000    -449.551     449.551
# C(region_name)[T.Краснодарский]         1352.0714    985.339      1.372      0.170    -579.157    3283.300
# C(region_name)[T.Курганская]            1.674e-12    229.367    7.3e-15      1.000    -449.551     449.551
# C(region_name)[T.Ленинградская]          434.9167    230.392      1.888      0.059     -16.643     886.476
# C(region_name)[T.Московская]             470.4300    219.060      2.147      0.032      41.080     899.780
# C(region_name)[T.Мурманская]              11.2500    233.677      0.048      0.962    -446.748     469.248
# C(region_name)[T.Омская]                1792.0000    914.443      1.960      0.050      -0.275    3584.275
# C(region_name)[T.Оренбургская]          2826.1250   1863.116      1.517      0.129    -825.515    6477.765
# C(region_name)[T.Орловская]              650.0000    217.065      2.994      0.003     224.561    1075.439
# C(region_name)[T.Пермский]               273.0000    327.244      0.834      0.404    -368.386     914.386
# C(region_name)[T.Ростовская]              75.0000    261.301      0.287      0.774    -437.141     587.141
# C(region_name)[T.Рязанская]             4.045e-12    229.367   1.76e-14      1.000    -449.551     449.551
# C(region_name)[T.Самарская]              708.6250    307.968      2.301      0.021     105.018    1312.232
# C(region_name)[T.Саратовская]            250.0000    222.731      1.122      0.262    -186.544     686.544
# C(region_name)[T.Сахалинская]            250.0000    222.731      1.122      0.262    -186.544     686.544
# C(region_name)[T.Ставропольский]       -1.237e-12    198.637  -6.23e-15      1.000    -389.322     389.322
# C(region_name)[T.Тамбовская]             153.7500    215.326      0.714      0.475    -268.281     575.781
# C(region_name)[T.Тверская]               181.1250    220.281      0.822      0.411    -250.618     612.868
# C(region_name)[T.Тульская]               227.5000    232.805      0.977      0.328    -228.789     683.789
# C(region_name)[T.Удмуртская]              97.5000    206.827      0.471      0.637    -307.873     502.873
# C(region_name)[T.Ульяновская]           -3.15e-13    198.637  -1.59e-15      1.000    -389.322     389.322
# C(region_name)[T.Хабаровский]           1943.0000   1338.869      1.451      0.147    -681.134    4567.134
# C(region_name)[T.Хакасия]                 75.7500    192.832      0.393      0.694    -302.195     453.695
# C(region_name)[T.Ярославская]             10.0000    225.825      0.044      0.965    -432.609     452.609
# C(year)[T.2013]                           29.7324     60.774      0.489      0.625     -89.382     148.847
# group                                    614.5648    184.137      3.338      0.001     253.664     975.466
# post                                      29.7324     60.774      0.489      0.625     -89.382     148.847
# group:post                               -39.6704    431.322     -0.092      0.927    -885.046     805.705
# ==============================================================================
# Omnibus:                      520.602   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           251303.118
# Skew:                          10.530   Prob(JB):                         0.00
# Kurtosis:                     147.199   Cond. No.                     2.77e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# [2] The smallest eigenvalue is 7.85e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Водопровод: -2051.99 (p-value: 0.388)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Водопровод   R-squared:                       0.226
# Model:                            OLS   Adj. R-squared:                  0.087
# Method:                 Least Squares   F-statistic:                     3.260
# Date:                Mon, 15 Sep 2025   Prob (F-statistic):           4.19e-09
# Time:                        15:28:15   Log-Likelihood:                -2995.1
# No. Observations:                 284   AIC:                             6078.
# Df Residuals:                     240   BIC:                             6239.
# Df Model:                          43
# Covariance Type:                  HC1
# ==========================================================================================================
#                                              coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                               2276.2576   3685.490      0.618      0.537   -4947.170    9499.685
# C(region_name)[T.Алтай]                -3100.0000   3632.188     -0.853      0.393   -1.02e+04    4018.958
# C(region_name)[T.Амурская]             -3490.7500   3642.343     -0.958      0.338   -1.06e+04    3648.112
# C(region_name)[T.Архангельская]        -1917.0000   3574.766     -0.536      0.592   -8923.413    5089.413
# C(region_name)[T.Астраханская]          1.751e+04   9809.974      1.785      0.074   -1716.946    3.67e+04
# C(region_name)[T.Башкортостан]          -337.5000   3685.816     -0.092      0.927   -7561.567    6886.567
# C(region_name)[T.Брянская]              1.709e+04   1.91e+04      0.895      0.371   -2.03e+04    5.45e+04
# C(region_name)[T.Вологодская]          -2246.0833   3570.116     -0.629      0.529   -9243.382    4751.215
# C(region_name)[T.Воронежская]           5425.0000   4515.623      1.201      0.230   -3425.458    1.43e+04
# C(region_name)[T.Дагестан]             -3356.2500   3554.746     -0.944      0.345   -1.03e+04    3610.924
# C(region_name)[T.Ивановская]           -3148.0000   3652.096     -0.862      0.389   -1.03e+04    4009.976
# C(region_name)[T.Иркутская]             1715.0000   4051.032      0.423      0.672   -6224.877    9654.877
# C(region_name)[T.Калининградская]        315.0000   3864.866      0.082      0.935   -7259.998    7889.998
# C(region_name)[T.Калужская]            -1927.0000   3740.330     -0.515      0.606   -9257.912    5403.912
# C(region_name)[T.Камчатский]           -3395.0000   3621.017     -0.938      0.348   -1.05e+04    3702.063
# C(region_name)[T.Карачаево-Черкесская] -1268.7500   3571.649     -0.355      0.722   -8269.054    5731.554
# C(region_name)[T.Кировская]              546.0000   4868.517      0.112      0.911   -8996.117    1.01e+04
# C(region_name)[T.Коми]                 -3775.0000   3649.731     -1.034      0.301   -1.09e+04    3378.342
# C(region_name)[T.Краснодарский]         5740.8786   3937.524      1.458      0.145   -1976.526    1.35e+04
# C(region_name)[T.Курганская]           -1212.5000   3921.745     -0.309      0.757   -8898.979    6473.979
# C(region_name)[T.Ленинградская]         -848.7917   3681.381     -0.231      0.818   -8064.166    6366.582
# C(region_name)[T.Московская]           -2471.4500   3555.538     -0.695      0.487   -9440.176    4497.276
# C(region_name)[T.Мурманская]           -3679.0000   3661.794     -1.005      0.315   -1.09e+04    3497.985
# C(region_name)[T.Омская]                2887.5000   3947.301      0.732      0.464   -4849.069    1.06e+04
# C(region_name)[T.Оренбургская]          4280.0000   4208.418      1.017      0.309   -3968.349    1.25e+04
# C(region_name)[T.Орловская]            -1727.5000   3583.458     -0.482      0.630   -8750.948    5295.948
# C(region_name)[T.Пермский]              1103.5000   3671.885      0.301      0.764   -6093.263    8300.263
# C(region_name)[T.Ростовская]            -907.5000   3632.196     -0.250      0.803   -8026.474    6211.474
# C(region_name)[T.Рязанская]            -1057.5000   4012.960     -0.264      0.792   -8922.757    6807.757
# C(region_name)[T.Самарская]             -984.0000   3641.858     -0.270      0.787   -8121.911    6153.911
# C(region_name)[T.Саратовская]           -475.0000   3655.310     -0.130      0.897   -7639.276    6689.276
# C(region_name)[T.Сахалинская]          -1425.0000   3640.576     -0.391      0.695   -8560.397    5710.397
# C(region_name)[T.Ставропольский]       -3769.2500   3592.228     -1.049      0.294   -1.08e+04    3271.388
# C(region_name)[T.Тамбовская]           -2838.7500   3718.382     -0.763      0.445   -1.01e+04    4449.145
# C(region_name)[T.Тверская]             -2907.5000   3656.763     -0.795      0.427   -1.01e+04    4259.623
# C(region_name)[T.Тульская]              3190.4812   3942.144      0.809      0.418   -4535.980    1.09e+04
# C(region_name)[T.Удмуртская]              61.5000   3769.132      0.016      0.987   -7325.863    7448.863
# C(region_name)[T.Ульяновская]          -3775.0000   3592.029     -1.051      0.293   -1.08e+04    3265.248
# C(region_name)[T.Хабаровский]           5279.2500   5294.477      0.997      0.319   -5097.735    1.57e+04
# C(region_name)[T.Хакасия]              -2167.0250   3600.358     -0.602      0.547   -9223.598    4889.548
# C(region_name)[T.Ярославская]          -3572.5000   3668.546     -0.974      0.330   -1.08e+04    3617.718
# C(year)[T.2013]                          -12.9507    403.071     -0.032      0.974    -802.955     777.054
# group                                   4049.3810   2191.427      1.848      0.065    -245.737    8344.498
# post                                     -12.9507    403.071     -0.032      0.974    -802.955     777.054
# group:post                             -2051.9894   2375.836     -0.864      0.388   -6708.543    2604.564
# ==============================================================================
# Omnibus:                      500.386   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           218815.997
# Skew:                           9.710   Prob(JB):                         0.00
# Kurtosis:                     137.589   Cond. No.                     2.77e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# [2] The smallest eigenvalue is 7.85e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
datasets = ['2012t.csv', '2012tM.csv', '2012tM2.csv', '2012t+.csv']

# Годы для анализа
years_combinations = [
    [2010, 2014],
    [2010, 2015],
    [2010, 2016]
]

for dataset in datasets:
    print(f"\n{dataset}")
    print("=" * 50)
    
    # Загрузка данных
    df = pd.read_csv(dataset)
    
    # Подготовка данных
    protest = df[[
        'year', 
        'municipality_protest', 
        'oktmo_protest', 
        'Жилье (1000 м2)_protest', 
        'Дороги (%)_protest', 
        'Канализация (1 м)_protest', 
        'Водопровод (1 метр)_protest',
        'region_name_protest'
    ]]

    protest.columns = [
        'year', 
        'municipality', 
        'oktmo', 
        'Жилье', 
        'Дороги', 
        'Канализация', 
        'Водопровод',
        'region_name'
    ]
    protest['group'] = 1  

    event = df[[
        'year', 
        'municipality_event', 
        'oktmo_event',
        'Жилье (1000 м2)_event', 
        'Дороги (%)_event', 
        'Канализация (1 м)_event', 
        'Водопровод (1 метр)_event',
        'region_name_event'
    ]]
    event.columns = [
        'year', 
        'municipality', 
        'oktmo', 
        'Жилье', 
        'Дороги', 
        'Канализация', 
        'Водопровод',
        'region_name'
    ]
    event['group'] = 0  

    combined = pd.concat([protest, event], ignore_index=True)

    def run_did(data, outcome, years):
        data_filtered = data[data['year'].isin(years)].copy()
        data_filtered['post'] = (data_filtered['year'] == years[1]).astype(int)
        data_filtered = data_filtered.dropna(subset=[outcome, 'group', 'post'])
        
        formula = f'{outcome} ~ group + post + group:post + C(region_name) + C(year)'
        model = smf.ols(formula, data=data_filtered).fit(cov_type='HC1')
        return model

    for years in years_combinations:
        print(f"\nГоды: {years[0]} -- {years[1]}")
        
        results = {}
        for outcome in ['Жилье', 'Дороги', 'Канализация', 'Водопровод']:
            model = run_did(combined, outcome, years)
            results[outcome] = model

        print("Коэффициенты взаимодействия (group:post):")
        for outcome, model in results.items():
            coef = model.params.get('group:post', 0)
            pval = model.pvalues.get('group:post', 1)
            print(f"{outcome}: {coef:.2f} (p-value: {pval:.3f})")
# Out:
# 2012t.csv
# ==================================================
#
# Годы: 2010 -- 2014
# Коэффициенты взаимодействия (group:post):
# Жилье: 14.92 (p-value: 0.446)
# Дороги: 3.03 (p-value: 0.571)
# Канализация: -1556.25 (p-value: 0.278)
# Водопровод: -358.26 (p-value: 0.832)
#
# Годы: 2010 -- 2015
# Коэффициенты взаимодействия (group:post):
# Жилье: -2.57 (p-value: 0.880)
# Дороги: 12.70 (p-value: 0.018)
# Канализация: -1830.26 (p-value: 0.200)
# Водопровод: -1362.01 (p-value: 0.390)
#
# Годы: 2010 -- 2016
# Коэффициенты взаимодействия (group:post):
# Жилье: 88.05 (p-value: 0.410)
# Дороги: 10.55 (p-value: 0.048)
# Канализация: -1810.34 (p-value: 0.207)
# Водопровод: -794.89 (p-value: 0.632)
#
# 2012tM.csv
# ==================================================
#
# Годы: 2010 -- 2014
# Коэффициенты взаимодействия (group:post):
# Жилье: 10.71 (p-value: 0.544)
# Дороги: 7.38 (p-value: 0.182)
# Канализация: -1813.56 (p-value: 0.207)
# Водопровод: -924.32 (p-value: 0.586)
#
# Годы: 2010 -- 2015
# Коэффициенты взаимодействия (group:post):
# Жилье: -7.32 (p-value: 0.651)
# Дороги: 12.44 (p-value: 0.025)
# Канализация: -2124.28 (p-value: 0.139)
# Водопровод: -1343.16 (p-value: 0.420)
#
# Годы: 2010 -- 2016
# Коэффициенты взаимодействия (group:post):
# Жилье: 83.17 (p-value: 0.471)
# Дороги: 10.19 (p-value: 0.065)
# Канализация: -1941.97 (p-value: 0.177)
# Водопровод: -1462.11 (p-value: 0.403)
#
# 2012tM2.csv
# ==================================================
#
# Годы: 2010 -- 2014
# Коэффициенты взаимодействия (group:post):
# Жилье: 12.53 (p-value: 0.480)
# Дороги: 7.88 (p-value: 0.155)
# Канализация: -1820.67 (p-value: 0.205)
# Водопровод: -1102.06 (p-value: 0.519)
#
# Годы: 2010 -- 2015
# Коэффициенты взаимодействия (group:post):
# Жилье: -6.67 (p-value: 0.683)
# Дороги: 13.74 (p-value: 0.013)
# Канализация: -2115.18 (p-value: 0.140)
# Водопровод: -1325.54 (p-value: 0.417)
#
# Годы: 2010 -- 2016
# Коэффициенты взаимодействия (group:post):
# Жилье: 81.65 (p-value: 0.479)
# Дороги: 10.84 (p-value: 0.050)
# Канализация: -1946.84 (p-value: 0.176)
# Водопровод: -1330.08 (p-value: 0.441)
#
# 2012t+.csv
# ==================================================
#
# Годы: 2010 -- 2014
# Коэффициенты взаимодействия (group:post):
# Жилье: 14.03 (p-value: 0.424)
# Дороги: 2.28 (p-value: 0.669)
# Канализация: -1892.87 (p-value: 0.180)
# Водопровод: -1724.64 (p-value: 0.315)
#
# Годы: 2010 -- 2015
# Коэффициенты взаимодействия (group:post):
# Жилье: -3.68 (p-value: 0.828)
# Дороги: 12.00 (p-value: 0.024)
# Канализация: -2119.37 (p-value: 0.133)
# Водопровод: -2723.83 (p-value: 0.086)
#
# Годы: 2010 -- 2016
# Коэффициенты взаимодействия (group:post):
# Жилье: 72.76 (p-value: 0.512)
# Дороги: 12.44 (p-value: 0.016)
# Канализация: -2072.09 (p-value: 0.142)
# Водопровод: -2002.01 (p-value: 0.219)

# %%
datasets = ['2010t5_2.csv', '2010t5M_2.csv', '2010t5M2_2.csv', '2010t5+_2.csv']

# Годы для анализа
years_combinations = [
    [2008, 2013],
    [2008, 2014],
    [2008, 2015]
]

for dataset in datasets:
    print(f"\n{dataset}")
    print("=" * 50)
    
    # Загрузка данных
    df = pd.read_csv(dataset)
    
    # Подготовка данных
    protest = df[[
        'year', 
        'municipality_protest', 
        'oktmo_protest', 
        'Жилье (1000 м2)_protest', 
        'Дороги (%)_protest', 
        'Канализация (1 м)_protest', 
        'Водопровод (1 метр)_protest',
        'region_name_protest'
    ]]

    protest.columns = [
        'year', 
        'municipality', 
        'oktmo', 
        'Жилье', 
        'Дороги', 
        'Канализация', 
        'Водопровод',
        'region_name'
    ]
    protest['group'] = 1  

    event = df[[
        'year', 
        'municipality_event', 
        'oktmo_event',
        'Жилье (1000 м2)_event', 
        'Дороги (%)_event', 
        'Канализация (1 м)_event', 
        'Водопровод (1 метр)_event',
        'region_name_event'
    ]]
    event.columns = [
        'year', 
        'municipality', 
        'oktmo', 
        'Жилье', 
        'Дороги', 
        'Канализация', 
        'Водопровод',
        'region_name'
    ]
    event['group'] = 0  

    combined = pd.concat([protest, event], ignore_index=True)

    def run_did(data, outcome, years):
        data_filtered = data[data['year'].isin(years)].copy()
        data_filtered['post'] = (data_filtered['year'] == years[1]).astype(int)
        data_filtered = data_filtered.dropna(subset=[outcome, 'group', 'post'])
        
        formula = f'{outcome} ~ group + post + group:post + C(region_name) + C(year)'
        model = smf.ols(formula, data=data_filtered).fit(cov_type='HC1')
        return model

    for years in years_combinations:
        print(f"\nГоды: {years[0]} -- {years[1]}")
        
        results = {}
        for outcome in ['Жилье', 'Дороги', 'Канализация', 'Водопровод']:
            model = run_did(combined, outcome, years)
            results[outcome] = model

        print("Коэффициенты взаимодействия (group:post):")
        for outcome, model in results.items():
            coef = model.params.get('group:post', 0)
            pval = model.pvalues.get('group:post', 1)
            print(f"{outcome}: {coef:.2f} (p-value: {pval:.3f})")
# Out:
# 2010t5_2.csv
# ==================================================
#
# Годы: 2008 -- 2013
# Коэффициенты взаимодействия (group:post):
# Жилье: -3.00 (p-value: 0.894)
# Дороги: 13.07 (p-value: 0.004)
# Канализация: -60.34 (p-value: 0.739)
# Водопровод: 1342.35 (p-value: 0.093)
#
# Годы: 2008 -- 2014
# Коэффициенты взаимодействия (group:post):
# Жилье: -4.46 (p-value: 0.842)
# Дороги: 14.36 (p-value: 0.002)
# Канализация: 2.08 (p-value: 0.992)
# Водопровод: 760.60 (p-value: 0.343)
#
# Годы: 2008 -- 2015
# Коэффициенты взаимодействия (group:post):
# Жилье: -22.47 (p-value: 0.288)
# Дороги: 14.59 (p-value: 0.002)
# Канализация: -103.22 (p-value: 0.557)
# Водопровод: 414.15 (p-value: 0.570)
#
# 2010t5M_2.csv
# ==================================================
#
# Годы: 2008 -- 2013
# Коэффициенты взаимодействия (group:post):
# Жилье: -12.75 (p-value: 0.530)
# Дороги: 12.23 (p-value: 0.008)
# Канализация: -192.30 (p-value: 0.233)
# Водопровод: 736.95 (p-value: 0.383)
#
# Годы: 2008 -- 2014
# Коэффициенты взаимодействия (group:post):
# Жилье: -11.97 (p-value: 0.551)
# Дороги: 12.83 (p-value: 0.007)
# Канализация: 69.37 (p-value: 0.686)
# Водопровод: 443.09 (p-value: 0.570)
#
# Годы: 2008 -- 2015
# Коэффициенты взаимодействия (group:post):
# Жилье: -38.43 (p-value: 0.042)
# Дороги: 12.72 (p-value: 0.007)
# Канализация: -158.45 (p-value: 0.293)
# Водопровод: 612.17 (p-value: 0.399)
#
# 2010t5M2_2.csv
# ==================================================
#
# Годы: 2008 -- 2013
# Коэффициенты взаимодействия (group:post):
# Жилье: -8.96 (p-value: 0.659)
# Дороги: 13.98 (p-value: 0.003)
# Канализация: -268.21 (p-value: 0.093)
# Водопровод: 438.73 (p-value: 0.581)
#
# Годы: 2008 -- 2014
# Коэффициенты взаимодействия (group:post):
# Жилье: -9.21 (p-value: 0.645)
# Дороги: 14.71 (p-value: 0.002)
# Канализация: -5.88 (p-value: 0.973)
# Водопровод: -46.45 (p-value: 0.953)
#
# Годы: 2008 -- 2015
# Коэффициенты взаимодействия (group:post):
# Жилье: -38.28 (p-value: 0.042)
# Дороги: 14.91 (p-value: 0.002)
# Канализация: -257.42 (p-value: 0.083)
# Водопровод: -35.35 (p-value: 0.959)
#
# 2010t5+_2.csv
# ==================================================
#
# Годы: 2008 -- 2013
# Коэффициенты взаимодействия (group:post):
# Жилье: 32.21 (p-value: 0.338)
# Дороги: 9.11 (p-value: 0.038)
# Канализация: -187.59 (p-value: 0.246)
# Водопровод: 614.67 (p-value: 0.373)
#
# Годы: 2008 -- 2014
# Коэффициенты взаимодействия (group:post):
# Жилье: 30.89 (p-value: 0.360)
# Дороги: 10.74 (p-value: 0.019)
# Канализация: 18.78 (p-value: 0.913)
# Водопровод: -14.51 (p-value: 0.985)
#
# Годы: 2008 -- 2015
# Коэффициенты взаимодействия (group:post):
# Жилье: 9.93 (p-value: 0.766)
# Дороги: 8.18 (p-value: 0.074)
# Канализация: -136.95 (p-value: 0.334)
# Водопровод: 521.95 (p-value: 0.376)

# %%
datasets = ['2010t6.csv', '2010t6M.csv', '2010t6M2.csv', '2010t6+.csv']

# Годы для анализа
years_combinations = [
    [2010, 2015],
    [2010, 2016],
    [2010, 2017]
]

for dataset in datasets:
    print(f"\n{dataset}")
    print("=" * 50)
    
    # Загрузка данных
    df = pd.read_csv(dataset)
    
    # Подготовка данных
    protest = df[[
        'year', 
        'municipality_protest', 
        'oktmo_protest', 
        'Жилье (1000 м2)_protest', 
        'Дороги (%)_protest', 
        'Канализация (1 м)_protest', 
        'Водопровод (1 метр)_protest',
        'region_name_protest'
    ]]

    protest.columns = [
        'year', 
        'municipality', 
        'oktmo', 
        'Жилье', 
        'Дороги', 
        'Канализация', 
        'Водопровод',
        'region_name'
    ]
    protest['group'] = 1  

    event = df[[
        'year', 
        'municipality_event', 
        'oktmo_event',
        'Жилье (1000 м2)_event', 
        'Дороги (%)_event', 
        'Канализация (1 м)_event', 
        'Водопровод (1 метр)_event',
        'region_name_event'
    ]]
    event.columns = [
        'year', 
        'municipality', 
        'oktmo', 
        'Жилье', 
        'Дороги', 
        'Канализация', 
        'Водопровод',
        'region_name'
    ]
    event['group'] = 0  

    combined = pd.concat([protest, event], ignore_index=True)

    def run_did(data, outcome, years):
        data_filtered = data[data['year'].isin(years)].copy()
        data_filtered['post'] = (data_filtered['year'] == years[1]).astype(int)
        data_filtered = data_filtered.dropna(subset=[outcome, 'group', 'post'])
        
        formula = f'{outcome} ~ group + post + group:post + C(region_name) + C(year)'
        model = smf.ols(formula, data=data_filtered).fit(cov_type='HC1')
        return model

    for years in years_combinations:
        print(f"\nГоды: {years[0]} -- {years[1]}")
        
        results = {}
        for outcome in ['Жилье', 'Дороги', 'Канализация', 'Водопровод']:
            model = run_did(combined, outcome, years)
            results[outcome] = model

        print("Коэффициенты взаимодействия (group:post):")
        for outcome, model in results.items():
            coef = model.params.get('group:post', 0)
            pval = model.pvalues.get('group:post', 1)
            print(f"{outcome}: {coef:.2f} (p-value: {pval:.3f})")
# Out:
# 2010t6.csv
# ==================================================
#
# Годы: 2010 -- 2015
# Коэффициенты взаимодействия (group:post):
# Жилье: -9.18 (p-value: 0.511)
# Дороги: 10.30 (p-value: 0.033)
# Канализация: -1794.05 (p-value: 0.143)
# Водопровод: -1035.59 (p-value: 0.445)
#
# Годы: 2010 -- 2016
# Коэффициенты взаимодействия (group:post):
# Жилье: 73.23 (p-value: 0.419)
# Дороги: 10.15 (p-value: 0.040)
# Канализация: -1803.77 (p-value: 0.144)
# Водопровод: -484.67 (p-value: 0.734)
#
# Годы: 2010 -- 2017
# Коэффициенты взаимодействия (group:post):
# Жилье: -21.16 (p-value: 0.108)
# Дороги: 19.06 (p-value: 0.000)
# Канализация: -1855.73 (p-value: 0.131)
# Водопровод: -1481.53 (p-value: 0.278)
#
# 2010t6M.csv
# ==================================================
#
# Годы: 2010 -- 2015
# Коэффициенты взаимодействия (group:post):
# Жилье: -5.38 (p-value: 0.704)
# Дороги: 11.98 (p-value: 0.017)
# Канализация: -1834.51 (p-value: 0.133)
# Водопровод: -1495.40 (p-value: 0.303)
#
# Годы: 2010 -- 2016
# Коэффициенты взаимодействия (group:post):
# Жилье: 71.23 (p-value: 0.465)
# Дороги: 11.75 (p-value: 0.020)
# Канализация: -1730.47 (p-value: 0.159)
# Водопровод: -1003.24 (p-value: 0.500)
#
# Годы: 2010 -- 2017
# Коэффициенты взаимодействия (group:post):
# Жилье: -25.37 (p-value: 0.034)
# Дороги: 16.37 (p-value: 0.001)
# Канализация: -1825.30 (p-value: 0.137)
# Водопровод: -1232.19 (p-value: 0.372)
#
# 2010t6M2.csv
# ==================================================
#
# Годы: 2010 -- 2015
# Коэффициенты взаимодействия (group:post):
# Жилье: -9.18 (p-value: 0.516)
# Дороги: 15.32 (p-value: 0.002)
# Канализация: -1847.49 (p-value: 0.131)
# Водопровод: -1794.65 (p-value: 0.206)
#
# Годы: 2010 -- 2016
# Коэффициенты взаимодействия (group:post):
# Жилье: 69.83 (p-value: 0.473)
# Дороги: 12.60 (p-value: 0.013)
# Канализация: -1788.19 (p-value: 0.145)
# Водопровод: -1255.64 (p-value: 0.395)
#
# Годы: 2010 -- 2017
# Коэффициенты взаимодействия (group:post):
# Жилье: -26.76 (p-value: 0.026)
# Дороги: 17.01 (p-value: 0.001)
# Канализация: -1828.17 (p-value: 0.135)
# Водопровод: -1482.18 (p-value: 0.280)
#
# 2010t6+.csv
# ==================================================
#
# Годы: 2010 -- 2015
# Коэффициенты взаимодействия (group:post):
# Жилье: -5.77 (p-value: 0.713)
# Дороги: 8.73 (p-value: 0.083)
# Канализация: -1824.74 (p-value: 0.127)
# Водопровод: -2036.28 (p-value: 0.137)
#
# Годы: 2010 -- 2016
# Коэффициенты взаимодействия (group:post):
# Жилье: 65.53 (p-value: 0.489)
# Дороги: 14.54 (p-value: 0.003)
# Канализация: -1716.93 (p-value: 0.152)
# Водопровод: -1277.42 (p-value: 0.363)
#
# Годы: 2010 -- 2017
# Коэффициенты взаимодействия (group:post):
# Жилье: -28.28 (p-value: 0.032)
# Дороги: 20.22 (p-value: 0.000)
# Канализация: -1824.25 (p-value: 0.128)
# Водопровод: -1698.52 (p-value: 0.205)

# %%
datasets = ['2010t4.csv', '2010t4М.csv', '2010t4М2.csv', '2010t4+.csv']

# Годы для анализа
years_combinations = [
    [2008, 2013],
    [2008, 2014],
    [2008, 2015]
]

for dataset in datasets:
    print(f"\n{dataset}")
    print("=" * 50)
    
    # Загрузка данных
    df = pd.read_csv(dataset)
    
    # Подготовка данных
    protest = df[[
        'year', 
        'municipality_protest', 
        'oktmo_protest', 
        'Жилье (1000 м2)_protest', 
        'Дороги (%)_protest', 
        'Канализация (1 м)_protest', 
        'Водопровод (1 метр)_protest',
        'region_name_protest'
    ]]

    protest.columns = [
        'year', 
        'municipality', 
        'oktmo', 
        'Жилье', 
        'Дороги', 
        'Канализация', 
        'Водопровод',
        'region_name'
    ]
    protest['group'] = 1  

    event = df[[
        'year', 
        'municipality_event', 
        'oktmo_event',
        'Жилье (1000 м2)_event', 
        'Дороги (%)_event', 
        'Канализация (1 м)_event', 
        'Водопровод (1 метр)_event',
        'region_name_event'
    ]]
    event.columns = [
        'year', 
        'municipality', 
        'oktmo', 
        'Жилье', 
        'Дороги', 
        'Канализация', 
        'Водопровод',
        'region_name'
    ]
    event['group'] = 0  

    combined = pd.concat([protest, event], ignore_index=True)

    def run_did(data, outcome, years):
        data_filtered = data[data['year'].isin(years)].copy()
        data_filtered['post'] = (data_filtered['year'] == years[1]).astype(int)
        data_filtered = data_filtered.dropna(subset=[outcome, 'group', 'post'])
        
        formula = f'{outcome} ~ group + post + group:post + C(region_name) + C(year)'
        model = smf.ols(formula, data=data_filtered).fit(cov_type='HC1')
        return model

    for years in years_combinations:
        print(f"\nГоды: {years[0]} -- {years[1]}")
        
        results = {}
        for outcome in ['Жилье', 'Дороги', 'Канализация', 'Водопровод']:
            model = run_did(combined, outcome, years)
            results[outcome] = model

        print("Коэффициенты взаимодействия (group:post):")
        for outcome, model in results.items():
            coef = model.params.get('group:post', 0)
            pval = model.pvalues.get('group:post', 1)
            print(f"{outcome}: {coef:.2f} (p-value: {pval:.3f})")
# Out:
# 2010t4.csv
# ==================================================
#
# Годы: 2008 -- 2013
# Коэффициенты взаимодействия (group:post):
# Жилье: 28.76 (p-value: 0.466)
# Дороги: -4.53 (p-value: 0.599)
# Канализация: -489.57 (p-value: 0.465)
# Водопровод: 487.93 (p-value: 0.777)
#
# Годы: 2008 -- 2014
# Коэффициенты взаимодействия (group:post):
# Жилье: 17.65 (p-value: 0.683)
# Дороги: -3.93 (p-value: 0.644)
# Канализация: -239.19 (p-value: 0.717)
# Водопровод: 967.45 (p-value: 0.580)
#
# Годы: 2008 -- 2015
# Коэффициенты взаимодействия (group:post):
# Жилье: -125.20 (p-value: 0.014)
# Дороги: -7.69 (p-value: 0.360)
# Канализация: -793.70 (p-value: 0.198)
# Водопровод: -357.64 (p-value: 0.828)
#
# 2010t4М.csv
# ==================================================
#
# Годы: 2008 -- 2013
# Коэффициенты взаимодействия (group:post):
# Жилье: 42.74 (p-value: 0.566)
# Дороги: -3.35 (p-value: 0.717)
# Канализация: -221.02 (p-value: 0.752)
# Водопровод: -910.31 (p-value: 0.548)
#
# Годы: 2008 -- 2014
# Коэффициенты взаимодействия (group:post):
# Жилье: 31.68 (p-value: 0.661)
# Дороги: -1.22 (p-value: 0.891)
# Канализация: 19.42 (p-value: 0.976)
# Водопровод: -1892.30 (p-value: 0.216)
#
# Годы: 2008 -- 2015
# Коэффициенты взаимодействия (group:post):
# Жилье: -141.23 (p-value: 0.015)
# Дороги: 9.16 (p-value: 0.269)
# Канализация: -263.59 (p-value: 0.673)
# Водопровод: -2107.28 (p-value: 0.136)
#
# 2010t4М2.csv
# ==================================================
#
# Годы: 2008 -- 2013
# Коэффициенты взаимодействия (group:post):
# Жилье: 40.91 (p-value: 0.582)
# Дороги: 0.20 (p-value: 0.982)
# Канализация: -486.51 (p-value: 0.488)
# Водопровод: -520.78 (p-value: 0.758)
#
# Годы: 2008 -- 2014
# Коэффициенты взаимодействия (group:post):
# Жилье: 28.08 (p-value: 0.697)
# Дороги: 1.42 (p-value: 0.868)
# Канализация: -285.36 (p-value: 0.675)
# Водопровод: -632.52 (p-value: 0.682)
#
# Годы: 2008 -- 2015
# Коэффициенты взаимодействия (group:post):
# Жилье: -144.33 (p-value: 0.012)
# Дороги: 8.72 (p-value: 0.273)
# Канализация: -611.54 (p-value: 0.332)
# Водопровод: -1293.70 (p-value: 0.382)
#
# 2010t4+.csv
# ==================================================
#
# Годы: 2008 -- 2013
# Коэффициенты взаимодействия (group:post):
# Жилье: 43.06 (p-value: 0.552)
# Дороги: -1.05 (p-value: 0.908)
# Канализация: -548.21 (p-value: 0.334)
# Водопровод: 290.12 (p-value: 0.834)
#
# Годы: 2008 -- 2014
# Коэффициенты взаимодействия (group:post):
# Жилье: 30.44 (p-value: 0.669)
# Дороги: -11.83 (p-value: 0.192)
# Канализация: -489.67 (p-value: 0.416)
# Водопровод: -14.37 (p-value: 0.992)
#
# Годы: 2008 -- 2015
# Коэффициенты взаимодействия (group:post):
# Жилье: -126.67 (p-value: 0.030)
# Дороги: 1.71 (p-value: 0.841)
# Канализация: -909.08 (p-value: 0.089)
# Водопровод: -1007.39 (p-value: 0.452)

# %%
datasets = ['2010t3.csv', '2010t3М.csv', '2010t3М2.csv', '2010t3+.csv']

# Годы для анализа
years_combinations = [
    [2010, 2014],
    [2010, 2015],
    [2010, 2016]
]

for dataset in datasets:
    print(f"\n{dataset}")
    print("=" * 50)
    
    # Загрузка данных
    df = pd.read_csv(dataset)
    
    # Подготовка данных
    protest = df[[
        'year', 
        'municipality_protest', 
        'oktmo_protest', 
        'Жилье (1000 м2)_protest', 
        'Дороги (%)_protest', 
        'Канализация (1 м)_protest', 
        'Водопровод (1 метр)_protest',
        'region_name_protest'
    ]]

    protest.columns = [
        'year', 
        'municipality', 
        'oktmo', 
        'Жилье', 
        'Дороги', 
        'Канализация', 
        'Водопровод',
        'region_name'
    ]
    protest['group'] = 1  

    event = df[[
        'year', 
        'municipality_event', 
        'oktmo_event',
        'Жилье (1000 м2)_event', 
        'Дороги (%)_event', 
        'Канализация (1 м)_event', 
        'Водопровод (1 метр)_event',
        'region_name_event'
    ]]
    event.columns = [
        'year', 
        'municipality', 
        'oktmo', 
        'Жилье', 
        'Дороги', 
        'Канализация', 
        'Водопровод',
        'region_name'
    ]
    event['group'] = 0  

    combined = pd.concat([protest, event], ignore_index=True)

    def run_did(data, outcome, years):
        data_filtered = data[data['year'].isin(years)].copy()
        data_filtered['post'] = (data_filtered['year'] == years[1]).astype(int)
        data_filtered = data_filtered.dropna(subset=[outcome, 'group', 'post'])
        
        formula = f'{outcome} ~ group + post + group:post + C(region_name) + C(year)'
        model = smf.ols(formula, data=data_filtered).fit(cov_type='HC1')
        return model

    for years in years_combinations:
        print(f"\nГоды: {years[0]} -- {years[1]}")
        
        results = {}
        for outcome in ['Жилье', 'Дороги', 'Канализация', 'Водопровод']:
            model = run_did(combined, outcome, years)
            results[outcome] = model

        print("Коэффициенты взаимодействия (group:post):")
        for outcome, model in results.items():
            coef = model.params.get('group:post', 0)
            pval = model.pvalues.get('group:post', 1)
            print(f"{outcome}: {coef:.2f} (p-value: {pval:.3f})")
# Out:
# 2010t3.csv
# ==================================================
#
# Годы: 2010 -- 2014
# Коэффициенты взаимодействия (group:post):
# Жилье: -13.34 (p-value: 0.790)
# Дороги: -2.45 (p-value: 0.777)
# Канализация: 3033.80 (p-value: 0.321)
# Водопровод: -2970.69 (p-value: 0.133)
#
# Годы: 2010 -- 2015
# Коэффициенты взаимодействия (group:post):
# Жилье: -184.83 (p-value: 0.004)
# Дороги: -2.21 (p-value: 0.808)
# Канализация: 2935.21 (p-value: 0.331)
# Водопровод: -2595.79 (p-value: 0.112)
#
# Годы: 2010 -- 2016
# Коэффициенты взаимодействия (group:post):
# Жилье: -190.34 (p-value: 0.003)
# Дороги: -1.02 (p-value: 0.913)
# Канализация: 3060.89 (p-value: 0.313)
# Водопровод: -2934.25 (p-value: 0.127)
#
# 2010t3М.csv
# ==================================================
#
# Годы: 2010 -- 2014
# Коэффициенты взаимодействия (group:post):
# Жилье: -14.53 (p-value: 0.853)
# Дороги: 7.06 (p-value: 0.426)
# Канализация: 4.04 (p-value: 0.994)
# Водопровод: -1946.37 (p-value: 0.313)
#
# Годы: 2010 -- 2015
# Коэффициенты взаимодействия (group:post):
# Жилье: -233.69 (p-value: 0.000)
# Дороги: 5.88 (p-value: 0.522)
# Канализация: -345.48 (p-value: 0.323)
# Водопровод: -2311.44 (p-value: 0.216)
#
# Годы: 2010 -- 2016
# Коэффициенты взаимодействия (group:post):
# Жилье: -242.07 (p-value: 0.000)
# Дороги: 13.47 (p-value: 0.146)
# Канализация: -70.61 (p-value: 0.866)
# Водопровод: -1916.33 (p-value: 0.240)
#
# 2010t3М2.csv
# ==================================================
#
# Годы: 2010 -- 2014
# Коэффициенты взаимодействия (group:post):
# Жилье: -14.85 (p-value: 0.850)
# Дороги: 8.08 (p-value: 0.345)
# Канализация: 146.08 (p-value: 0.767)
# Водопровод: -1904.27 (p-value: 0.323)
#
# Годы: 2010 -- 2015
# Коэффициенты взаимодействия (group:post):
# Жилье: -235.91 (p-value: 0.000)
# Дороги: 3.65 (p-value: 0.694)
# Канализация: -326.92 (p-value: 0.348)
# Водопровод: -2941.19 (p-value: 0.119)
#
# Годы: 2010 -- 2016
# Коэффициенты взаимодействия (group:post):
# Жилье: -245.22 (p-value: 0.000)
# Дороги: 10.64 (p-value: 0.258)
# Канализация: -99.60 (p-value: 0.817)
# Водопровод: -2370.94 (p-value: 0.146)
#
# 2010t3+.csv
# ==================================================
#
# Годы: 2010 -- 2014
# Коэффициенты взаимодействия (group:post):
# Жилье: -4.44 (p-value: 0.959)
# Дороги: -12.08 (p-value: 0.260)
# Канализация: 103.17 (p-value: 0.874)
# Водопровод: -1853.01 (p-value: 0.389)
#
# Годы: 2010 -- 2015
# Коэффициенты взаимодействия (group:post):
# Жилье: -195.44 (p-value: 0.007)
# Дороги: -4.23 (p-value: 0.681)
# Канализация: 55.97 (p-value: 0.902)
# Водопровод: -1284.75 (p-value: 0.497)
#
# Годы: 2010 -- 2016
# Коэффициенты взаимодействия (group:post):
# Жилье: -214.30 (p-value: 0.002)
# Дороги: -0.33 (p-value: 0.974)
# Канализация: 192.89 (p-value: 0.722)
# Водопровод: -1148.52 (p-value: 0.578)
